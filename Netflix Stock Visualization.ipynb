# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
netflix_data = pd.read_csv('NFLX.csv',index_col='Date')
netflix_data
# Out:
#                   Open        High         Low       Close   Adj Close  \
# Date
# 2019-06-24  370.269989  375.000000  370.200012  371.040009  371.040009
# 2019-06-25  370.750000  371.000000  358.290009  360.299988  360.299988
# 2019-06-26  361.600006  366.790009  361.600006  362.200012  362.200012
# 2019-06-27  363.200012  370.850006  363.200012  370.019989  370.019989
# 2019-06-28  370.260010  371.540009  364.869995  367.320007  367.320007
# ...                ...         ...         ...         ...         ...
# 2020-06-16  425.760010  437.959991  425.179993  436.130005  436.130005
# 2020-06-17  441.820007  450.459991  439.220001  447.769989  447.769989
# 2020-06-18  448.730011  452.760010  442.799988  449.869995  449.869995
# 2020-06-19  449.119995  453.970001  445.600006  453.720001  453.720001
# 2020-06-22  455.010010  468.589996  454.209991  468.040009  468.040009
#
#              Volume
# Date
# 2019-06-24  4830200
# 2019-06-25  5750400
# 2019-06-26  3669700
# ...

# %%
netflix_np=netflix_data['Volume'].values
netflix_np
# Out:
# array([ 4830200,  5750400,  3669700,  4138600,  4592700,  4992600,
#         3625000,  3799000,  3732200,  3113400,  6932800,  5878800,
#         4336300,  6636900,  7944700,  5863200, 13639500, 31305900,
#        16302500, 17718000,  9171100, 11961800, 10798500, 10847500,
#         5782800,  6029300,  6259500,  6563200,  6280300,  8692500,
#         6179100,  9322400,  5905900,  5349100,  6531700,  5289400,
#         7355800,  9629200,  6905800,  4942200,  7349900,  5685400,
#         4974200,  6324900,  4695700,  6309400,  3955700,  4388500,
#         4446400,  3682800,  4652500,  8966800,  5166600,  8232700,
#        12320200,  7405900,  5010900,  6583100,  5307400,  4777100,
#         7811100,  8461300, 23832800, 13478600, 16338200, 11643800,
#         7684000,  7328300,  6727200,  8650300,  7659100,  8951000,
#         9890400,  6525600,  6276400,  6794400, 10809100,  8786100,
#         5513200,  7685600, 16175900, 38258900, 23429900, 12599200,
# ...

# %%
netflix_series=netflix_data['Volume']
netflix_series
# Out:
# Date
# 2019-06-24    4830200
# 2019-06-25    5750400
# 2019-06-26    3669700
# 2019-06-27    4138600
# 2019-06-28    4592700
#                ...
# 2020-06-16    5507900
# 2020-06-17    6522400
# 2020-06-18    4277600
# 2020-06-19    5934500
# 2020-06-22    6264600
# Name: Volume, Length: 252, dtype: int64

# %%
netflix_data['Volume'].plot(color='r', style='.-', legend=True)

# %%
netflix_data['Volume'].hist()

# %%
netflix_data['Volume'].plot(color='g',style='-',legend=True)
netflix_data['High'].plot(color='b',style='.',legend=True)
netflix_data['Low'].plot(color='y',style='.-',legend=True)
plt.savefig('netflix.jpg')
plt.show()

# %%
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-48-bba3802036a6> in <module>
# ----> 1 netflix_data['High'].plot(color='r',style='.',Legend=True)
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\plotting\_core.py in __call__(self, *args, **kwargs)
#     845                     data.columns = label_name
#     846
# --> 847         return plot_backend.plot(data, kind=kind, **kwargs)
#     848
#     849     __call__.__doc__ = __doc__
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\plotting\_matplotlib\__init__.py in plot(data, kind, **kwargs)
#      59             kwargs["ax"] = getattr(ax, "left_ax", ax)
#      60     plot_obj = PLOT_CLASSES[kind](data, **kwargs)
# ---> 61     plot_obj.generate()
#      62     plot_obj.draw()
#      63     return plot_obj.result
#
# ...

# %%
netflix_data['High'].plot(color='b',style='.',legend=True)

# %%
netflix_data['Volume'].plot(color='g',style='-',legend=True)
netflix_data['High'].plot(color='b',style='.',legend=True)
netflix_data['Low'].plot(color='y',style='.-',legend=True)
plt.savefig('netflix.jpg')
plt.show()
